# %% [markdown]
# *WE USE GRADIENT DESCENT TO SOLVE OUR PROBLEM*

# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=20)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=y,s=100)

# %% [markdown]
# *USING SKLEARN*

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression(solver='sag',penalty='l2')
lor.fit(X,y)
# Out:
# c:\Users\UDIT MANI TRIPATHI\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# LogisticRegression(penalty='l2', solver='sag')

# %%
print(lor.coef_)
print(lor.intercept_)
# Out:
# [[2.36770669 0.02169118]]
# [3.13922318]

# %%
m1=-(lor.coef_[0][0]/lor.coef_[0][1])
b1=-(lor.intercept_[0]/lor.coef_[0][1])
print(m1)
# Out:
# -109.15527758503141

# %%
x_input1=np.linspace(-3,3,100)
y_input1=m1*x_input1+b1

# %%
plt.plot(x_input1,y_input1,color='black')
plt.scatter(X[:,0],X[:,1],c=y,s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# *WE MAKE OUR OWN CLASS*

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
def gd(X,y):
    X=np.insert(X,0,1,axis=1)    # add 1 in front of every row of x matrix
    weights=np.ones(X.shape[1])  # initailize all the coefficients of line to 1
    lr=0.5

    for i in range(1000):
        y_hat=sigmoid(np.dot(X,weights))
        weights=weights+lr*(np.dot((y-y_hat),X)/X.shape[0])
    return weights[1:],weights[0]

# %%
coef_,intercept_=gd(X,y)
print(coef_)
print(intercept_)
# Out:
# [4.83926872 0.21182255]
# 5.83338864905325

# %%
m2=-(coef_[0]/coef_[1])
b2=-(intercept_/coef_[1])
print(m2,b2)
# Out:
# -22.84586207917223 -27.5390354119192

# %%
x_input2=np.linspace(-3,3,100)
y_input2=m2*x_input2+b2

# %%
plt.plot(x_input1,y_input1,color='black')
plt.plot(x_input2,y_input2,color='red')
plt.scatter(X[:,0],X[:,1],c=y,s=100)
plt.ylim(-3,4)
# Out:
# (-3.0, 4.0)

# %% [markdown]
# *I DON'T KNOW WHAT IS WRONG BUT BOTH THESE LINES SHOULD OVERLAP BEACUSE WE USE THE SAME FORMULA WHICH SKLEARN USE*
